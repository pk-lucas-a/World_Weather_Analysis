# %%
import os
filevar = os.path.join("weather_data", "cities.csv")

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import numpy as np
import requests
from citipy import citipy
# Import the API key.
from config import g_key
from config import weather_api_key
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# URL for Weather Map with API key
city = "Boston"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | polunochnoye
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | karratha
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | garowe
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | san ignacio
# Processing Record 14 of Set 1 | bambanglipuro
# Processing Record 15 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 1 | paamiut
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | pisco
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | saint-joseph
# Processing Record 23 of Set 1 | novikovo
# Processing Record 24 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 1 | sao miguel do araguaia
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | santa maria
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | wajir
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | yulara
# Processing Record 36 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 1 | huarmey
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | karmala
# Processing Record 41 of Set 1 | half moon bay
# Processing Record 42 of Set 1 | pringsewu
# Processing Record 43 of Set 1 | kamenka
# Processing Record 44 of Set 1 | zhangye
# Processing Record 45 of Set 1 | hervey bay
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | pontianak
# Processing Record 48 of Set 1 | caravelas
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | morant bay
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | port blair
# Processing Record 4 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | coihaique
# Processing Record 7 of Set 2 | viedma
# Processing Record 8 of Set 2 | richards bay
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | lower hutt
# Processing Record 12 of Set 2 | katobu
# Processing Record 13 of Set 2 | tarrafal
# Processing Record 14 of Set 2 | kudahuvadhoo
# Processing Record 15 of Set 2 | zhetysay
# Processing Record 16 of Set 2 | krasnoselkup
# Processing Record 17 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 2 | lokosovo
# Processing Record 19 of Set 2 | labuhan
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | college
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | kushmurun
# Processing Record 27 of Set 2 | durango
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | ridgecrest
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | tuatapere
# Processing Record 32 of Set 2 | bara
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | nuuk
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | ghatal
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | dekoa
# City not found. Skipping...
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | tomatlan
# Processing Record 47 of Set 2 | mataura
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | carbondale
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | bayangol
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | darnah
# Processing Record 4 of Set 3 | cansancao
# Processing Record 5 of Set 3 | sorland
# Processing Record 6 of Set 3 | lagos
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | shache
# Processing Record 9 of Set 3 | beloha
# Processing Record 10 of Set 3 | andra
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | te anau
# Processing Record 15 of Set 3 | waipawa
# Processing Record 16 of Set 3 | trairi
# Processing Record 17 of Set 3 | malaut
# Processing Record 18 of Set 3 | kieta
# Processing Record 19 of Set 3 | hami
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | honiara
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | neyshabur
# Processing Record 25 of Set 3 | nago
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | santa cruz del sur
# Processing Record 29 of Set 3 | plouzane
# Processing Record 30 of Set 3 | morehead
# Processing Record 31 of Set 3 | celestun
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | flinders
# Processing Record 35 of Set 3 | beyneu
# Processing Record 36 of Set 3 | maniitsoq
# Processing Record 37 of Set 3 | gillette
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | bekhtery
# Processing Record 40 of Set 3 | dingle
# Processing Record 41 of Set 3 | ilulissat
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | auki
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 3 | hun
# Processing Record 47 of Set 3 | porgera
# Processing Record 48 of Set 3 | masindi
# Processing Record 49 of Set 3 | alta floresta
# Processing Record 50 of Set 3 | amambai
# Processing Record 1 of Set 4 | sabha
# Processing Record 2 of Set 4 | seydi
# Processing Record 3 of Set 4 | nuevo progreso
# Processing Record 4 of Set 4 | sinnamary
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | ormara
# Processing Record 9 of Set 4 | rajgarh
# Processing Record 10 of Set 4 | choix
# Processing Record 11 of Set 4 | yerbogachen
# Processing Record 12 of Set 4 | nieves
# Processing Record 13 of Set 4 | baijiantan
# Processing Record 14 of Set 4 | biak
# Processing Record 15 of Set 4 | lensk
# Processing Record 16 of Set 4 | oistins
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | san felipe
# Processing Record 20 of Set 4 | tasiilaq
# Processing Record 21 of Set 4 | locri
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | sehithwa
# Processing Record 24 of Set 4 | los llanos de aridane
# Processing Record 25 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 4 | mubi
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | berlevag
# Processing Record 29 of Set 4 | balaipungut
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | kitui
# Processing Record 32 of Set 4 | mocuba
# Processing Record 33 of Set 4 | sao joao dos patos
# Processing Record 34 of Set 4 | krasnokamensk
# Processing Record 35 of Set 4 | codrington
# Processing Record 36 of Set 4 | fort collins
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | vila velha
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | strezhevoy
# Processing Record 41 of Set 4 | gornyak
# Processing Record 42 of Set 4 | port alfred
# Processing Record 43 of Set 4 | port hawkesbury
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | peleduy
# Processing Record 46 of Set 4 | lahij
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | rio gallegos
# Processing Record 49 of Set 4 | skibbereen
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | anito
# Processing Record 2 of Set 5 | pozo colorado
# Processing Record 3 of Set 5 | kasese
# Processing Record 4 of Set 5 | airai
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | sistranda
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | tessalit
# Processing Record 9 of Set 5 | rudnogorsk
# Processing Record 10 of Set 5 | kendari
# Processing Record 11 of Set 5 | puri
# Processing Record 12 of Set 5 | lasa
# Processing Record 13 of Set 5 | port-gentil
# Processing Record 14 of Set 5 | cidreira
# Processing Record 15 of Set 5 | ambulu
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | camapua
# Processing Record 18 of Set 5 | jiuquan
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | marsh harbour
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | atar
# Processing Record 26 of Set 5 | labinsk
# Processing Record 27 of Set 5 | maningrida
# Processing Record 28 of Set 5 | hovd
# Processing Record 29 of Set 5 | la ronge
# Processing Record 30 of Set 5 | totness
# Processing Record 31 of Set 5 | kuala terengganu
# Processing Record 32 of Set 5 | dalbandin
# Processing Record 33 of Set 5 | boaco
# Processing Record 34 of Set 5 | sorsk
# Processing Record 35 of Set 5 | sabla
# Processing Record 36 of Set 5 | utinga
# Processing Record 37 of Set 5 | pitimbu
# Processing Record 38 of Set 5 | kharitonovo
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | kondinskoye
# Processing Record 41 of Set 5 | jijiga
# Processing Record 42 of Set 5 | owando
# Processing Record 43 of Set 5 | shahrud
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | fort-shevchenko
# Processing Record 46 of Set 5 | la carolina
# Processing Record 47 of Set 5 | kibre mengist
# Processing Record 48 of Set 5 | barrow
# Processing Record 49 of Set 5 | uthal
# Processing Record 50 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | planeta rica
# Processing Record 2 of Set 6 | malakal
# Processing Record 3 of Set 6 | manturovo
# Processing Record 4 of Set 6 | east london
# Processing Record 5 of Set 6 | faya
# Processing Record 6 of Set 6 | phan thiet
# Processing Record 7 of Set 6 | kholodnyy
# Processing Record 8 of Set 6 | oleksandrivka
# Processing Record 9 of Set 6 | havre-saint-pierre
# Processing Record 10 of Set 6 | qasigiannguit
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | port lincoln
# Processing Record 14 of Set 6 | husavik
# Processing Record 15 of Set 6 | quesnel
# Processing Record 16 of Set 6 | cabo san lucas
# Processing Record 17 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 6 | acarau
# Processing Record 19 of Set 6 | urucui
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | taltal
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | bandarbeyla
# Processing Record 25 of Set 6 | rafaela
# Processing Record 26 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | saint-georges
# Processing Record 29 of Set 6 | kloulklubed
# Processing Record 30 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 6 | sinjar
# Processing Record 32 of Set 6 | algiers
# Processing Record 33 of Set 6 | gol
# Processing Record 34 of Set 6 | komsomolskiy
# Processing Record 35 of Set 6 | skegness
# Processing Record 36 of Set 6 | waingapu
# Processing Record 37 of Set 6 | cacoal
# Processing Record 38 of Set 6 | kyabram
# Processing Record 39 of Set 6 | cap malheureux
# Processing Record 40 of Set 6 | abbotsford
# Processing Record 41 of Set 6 | muros
# Processing Record 42 of Set 6 | ketchikan
# Processing Record 43 of Set 6 | buckeye
# Processing Record 44 of Set 6 | karambakkudi
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | bloomfield
# Processing Record 47 of Set 6 | stonewall
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | zanesville
# Processing Record 50 of Set 6 | lagoa vermelha
# Processing Record 1 of Set 7 | maku
# Processing Record 2 of Set 7 | bulancak
# Processing Record 3 of Set 7 | erie
# Processing Record 4 of Set 7 | maues
# Processing Record 5 of Set 7 | sawakin
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | sur
# Processing Record 8 of Set 7 | nizwa
# Processing Record 9 of Set 7 | constitucion
# Processing Record 10 of Set 7 | evensk
# Processing Record 11 of Set 7 | courtenay
# Processing Record 12 of Set 7 | kahului
# Processing Record 13 of Set 7 | kavieng
# Processing Record 14 of Set 7 | tuni
# Processing Record 15 of Set 7 | camopi
# Processing Record 16 of Set 7 | kichera
# Processing Record 17 of Set 7 | castro
# Processing Record 18 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | riyadh
# Processing Record 21 of Set 7 | goderich
# Processing Record 22 of Set 7 | orchard homes
# Processing Record 23 of Set 7 | puerto cabezas
# Processing Record 24 of Set 7 | aviles
# Processing Record 25 of Set 7 | chitral
# Processing Record 26 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 7 | puerto del rosario
# Processing Record 28 of Set 7 | gravelbourg
# Processing Record 29 of Set 7 | constantine
# Processing Record 30 of Set 7 | caibarien
# Processing Record 31 of Set 7 | santa isabel
# Processing Record 32 of Set 7 | porto novo
# Processing Record 33 of Set 7 | najran
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | pangnirtung
# Processing Record 36 of Set 7 | bhigvan
# Processing Record 37 of Set 7 | kabwe
# Processing Record 38 of Set 7 | margate
# Processing Record 39 of Set 7 | tambun
# Processing Record 40 of Set 7 | nara
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | maimon
# City not found. Skipping...
# Processing Record 43 of Set 7 | price
# Processing Record 44 of Set 7 | mugur-aksy
# Processing Record 45 of Set 7 | grand gaube
# Processing Record 46 of Set 7 | tarragona
# Processing Record 47 of Set 7 | chokurdakh
# Processing Record 48 of Set 7 | roma
# Processing Record 49 of Set 7 | velyka bilozerka
# Processing Record 50 of Set 7 | colares
# Processing Record 1 of Set 8 | svetlogorsk
# Processing Record 2 of Set 8 | zangakatun
# Processing Record 3 of Set 8 | asau
# Processing Record 4 of Set 8 | uyuni
# Processing Record 5 of Set 8 | pomabamba
# Processing Record 6 of Set 8 | iguape
# Processing Record 7 of Set 8 | kavaratti
# Processing Record 8 of Set 8 | bichena
# Processing Record 9 of Set 8 | aksu
# Processing Record 10 of Set 8 | caledon east
# Processing Record 11 of Set 8 | kapuskasing
# Processing Record 12 of Set 8 | bereda
# Processing Record 13 of Set 8 | brownsville
# Processing Record 14 of Set 8 | haines junction
# Processing Record 15 of Set 8 | thoen
# Processing Record 16 of Set 8 | bertoua
# Processing Record 17 of Set 8 | amalapuram
# Processing Record 18 of Set 8 | gasa
# Processing Record 19 of Set 8 | saldanha
# Processing Record 20 of Set 8 | dikson
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | nikolskoye
# Processing Record 23 of Set 8 | lyuban
# Processing Record 24 of Set 8 | karoi
# Processing Record 25 of Set 8 | taian
# Processing Record 26 of Set 8 | geraldton
# Processing Record 27 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 28 of Set 8 | gold coast
# Processing Record 29 of Set 8 | sibolga
# Processing Record 30 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 8 | antalaha
# Processing Record 32 of Set 8 | broken hill
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | kilindoni
# Processing Record 35 of Set 8 | yendi
# Processing Record 36 of Set 8 | mokolo
# Processing Record 37 of Set 8 | atambua
# Processing Record 38 of Set 8 | ipixuna
# Processing Record 39 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | dalnerechensk
# Processing Record 42 of Set 8 | rauma
# Processing Record 43 of Set 8 | yueyang
# Processing Record 44 of Set 8 | kimberley
# Processing Record 45 of Set 8 | pryazha
# Processing Record 46 of Set 8 | pundaguitan
# Processing Record 47 of Set 8 | tacoaleche
# Processing Record 48 of Set 8 | nouakchott
# Processing Record 49 of Set 8 | fortuna
# Processing Record 50 of Set 8 | ler
# Processing Record 1 of Set 9 | xining
# Processing Record 2 of Set 9 | tuapse
# Processing Record 3 of Set 9 | dzhebariki-khaya
# Processing Record 4 of Set 9 | kruisfontein
# Processing Record 5 of Set 9 | vao
# Processing Record 6 of Set 9 | pauini
# Processing Record 7 of Set 9 | nantucket
# Processing Record 8 of Set 9 | hofn
# Processing Record 9 of Set 9 | krutinka
# Processing Record 10 of Set 9 | yaan
# Processing Record 11 of Set 9 | san policarpo
# Processing Record 12 of Set 9 | sainte-maxime
# Processing Record 13 of Set 9 | denpasar
# Processing Record 14 of Set 9 | hendersonville
# Processing Record 15 of Set 9 | kochi
# Processing Record 16 of Set 9 | shingu
# Processing Record 17 of Set 9 | pingzhuang
# Processing Record 18 of Set 9 | dhangadhi
# Processing Record 19 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 9 | aleksandrovskoye
# Processing Record 21 of Set 9 | souillac
# Processing Record 22 of Set 9 | uglovskoye
# Processing Record 23 of Set 9 | avera
# Processing Record 24 of Set 9 | ati
# Processing Record 25 of Set 9 | kaeo
# Processing Record 26 of Set 9 | malumfashi
# Processing Record 27 of Set 9 | klaksvik
# Processing Record 28 of Set 9 | acapulco
# Processing Record 29 of Set 9 | palamos
# Processing Record 30 of Set 9 | bloemfontein
# Processing Record 31 of Set 9 | jiaojiang
# Processing Record 32 of Set 9 | ust-nera
# Processing Record 33 of Set 9 | kolobrzeg
# Processing Record 34 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 35 of Set 9 | ginir
# Processing Record 36 of Set 9 | bubaque
# Processing Record 37 of Set 9 | peniche
# Processing Record 38 of Set 9 | yongan
# Processing Record 39 of Set 9 | blensong
# City not found. Skipping...
# Processing Record 40 of Set 9 | abnub
# Processing Record 41 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 9 | sira
# Processing Record 43 of Set 9 | adrar
# Processing Record 44 of Set 9 | narrabri
# Processing Record 45 of Set 9 | kisesa
# Processing Record 46 of Set 9 | takoradi
# Processing Record 47 of Set 9 | gigmoto
# Processing Record 48 of Set 9 | luderitz
# Processing Record 49 of Set 9 | ust-tarka
# Processing Record 50 of Set 9 | puerto maldonado
# Processing Record 1 of Set 10 | along
# Processing Record 2 of Set 10 | monte alegre de minas
# Processing Record 3 of Set 10 | wawa
# Processing Record 4 of Set 10 | sao felix do xingu
# Processing Record 5 of Set 10 | marabba
# Processing Record 6 of Set 10 | ban nahin
# Processing Record 7 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 10 | shimoda
# Processing Record 9 of Set 10 | jining
# Processing Record 10 of Set 10 | bedi
# Processing Record 11 of Set 10 | dawson creek
# Processing Record 12 of Set 10 | sao gabriel da cachoeira
# Processing Record 13 of Set 10 | bud
# Processing Record 14 of Set 10 | savelugu
# Processing Record 15 of Set 10 | zhanaozen
# Processing Record 16 of Set 10 | canon city
# Processing Record 17 of Set 10 | port hardy
# Processing Record 18 of Set 10 | sidi ali
# Processing Record 19 of Set 10 | bilma
# Processing Record 20 of Set 10 | chardara
# Processing Record 21 of Set 10 | oussouye
# Processing Record 22 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 23 of Set 10 | kurumkan
# Processing Record 24 of Set 10 | aykhal
# Processing Record 25 of Set 10 | la asuncion
# Processing Record 26 of Set 10 | chapais
# Processing Record 27 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 28 of Set 10 | panguna
# Processing Record 29 of Set 10 | muroto
# Processing Record 30 of Set 10 | isangel
# Processing Record 31 of Set 10 | hambantota
# Processing Record 32 of Set 10 | valparaiso
# Processing Record 33 of Set 10 | oparino
# Processing Record 34 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 10 | chirongui
# Processing Record 36 of Set 10 | juneau
# Processing Record 37 of Set 10 | monmouth
# Processing Record 38 of Set 10 | iquitos
# Processing Record 39 of Set 10 | narok
# Processing Record 40 of Set 10 | barranca
# Processing Record 41 of Set 10 | changping
# Processing Record 42 of Set 10 | sire
# Processing Record 43 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 10 | portland
# Processing Record 45 of Set 10 | liku
# Processing Record 46 of Set 10 | lagoa
# Processing Record 47 of Set 10 | katherine
# Processing Record 48 of Set 10 | qiongshan
# Processing Record 49 of Set 10 | grande prairie
# Processing Record 50 of Set 10 | naze
# Processing Record 1 of Set 11 | zyryanka
# Processing Record 2 of Set 11 | dongsheng
# Processing Record 3 of Set 11 | jiangyou
# Processing Record 4 of Set 11 | at-bashi
# Processing Record 5 of Set 11 | nishihara
# Processing Record 6 of Set 11 | serov
# Processing Record 7 of Set 11 | belyy yar
# Processing Record 8 of Set 11 | belaya gora
# Processing Record 9 of Set 11 | congonhas
# Processing Record 10 of Set 11 | carnarvon
# Processing Record 11 of Set 11 | menongue
# Processing Record 12 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 11 | kodar
# Processing Record 14 of Set 11 | nijar
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | kumluca
# Processing Record 17 of Set 11 | umm lajj
# Processing Record 18 of Set 11 | nefteyugansk
# Processing Record 19 of Set 11 | raudeberg
# Processing Record 20 of Set 11 | siniscola
# Processing Record 21 of Set 11 | alugan
# Processing Record 22 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 11 | saryg-sep
# Processing Record 24 of Set 11 | high level
# Processing Record 25 of Set 11 | matadi
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | vardo
# Processing Record 28 of Set 11 | arroio grande
# Processing Record 29 of Set 11 | aklavik
# Processing Record 30 of Set 11 | xuanhua
# Processing Record 31 of Set 11 | emerald
# Processing Record 32 of Set 11 | oeiras do para
# Processing Record 33 of Set 11 | puerto colombia
# Processing Record 34 of Set 11 | norman
# Processing Record 35 of Set 11 | paoua
# Processing Record 36 of Set 11 | noyabrsk
# Processing Record 37 of Set 11 | livingstonia
# Processing Record 38 of Set 11 | pingliang
# Processing Record 39 of Set 11 | ixhuatan
# Processing Record 40 of Set 11 | riviere-au-renard
# Processing Record 41 of Set 11 | mildura
# Processing Record 42 of Set 11 | libreville
# Processing Record 43 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 11 | udachnyy
# Processing Record 45 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 11 | thetford mines
# Processing Record 47 of Set 11 | kortkeros
# Processing Record 48 of Set 11 | baruun-urt
# Processing Record 49 of Set 11 | cayenne
# Processing Record 50 of Set 11 | brezovo
# Processing Record 1 of Set 12 | matiri
# Processing Record 2 of Set 12 | chapeco
# Processing Record 3 of Set 12 | villanueva
# Processing Record 4 of Set 12 | dolinsk
# Processing Record 5 of Set 12 | nocupetaro
# Processing Record 6 of Set 12 | mandurah
# Processing Record 7 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 12 | chumikan
# Processing Record 9 of Set 12 | kopavogur
# Processing Record 10 of Set 12 | keratea
# Processing Record 11 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 12 | miandrivazo
# Processing Record 13 of Set 12 | banepa
# Processing Record 14 of Set 12 | sochi
# Processing Record 15 of Set 12 | dakar
# Processing Record 16 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 12 | chingirlau
# Processing Record 19 of Set 12 | jaffna
# Processing Record 20 of Set 12 | padang
# Processing Record 21 of Set 12 | marystown
# Processing Record 22 of Set 12 | comonfort
# Processing Record 23 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 12 | westport
# Processing Record 25 of Set 12 | dayong
# Processing Record 26 of Set 12 | tripoli
# Processing Record 27 of Set 12 | verkhovazhye
# Processing Record 28 of Set 12 | ornskoldsvik
# Processing Record 29 of Set 12 | porto seguro
# Processing Record 30 of Set 12 | mancora
# Processing Record 31 of Set 12 | saint anthony
# Processing Record 32 of Set 12 | vanimo
# Processing Record 33 of Set 12 | campo gobierno
# Processing Record 34 of Set 12 | tanabe
# Processing Record 35 of Set 12 | lakselv
# Processing Record 36 of Set 12 | khorixas
# Processing Record 37 of Set 12 | vangaindrano
# Processing Record 38 of Set 12 | touros
# Processing Record 39 of Set 12 | isabela
# Processing Record 40 of Set 12 | ponta delgada
# Processing Record 41 of Set 12 | galveston
# Processing Record 42 of Set 12 | linxia
# Processing Record 43 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 44 of Set 12 | mahina
# Processing Record 45 of Set 12 | muriti
# Processing Record 46 of Set 12 | esso
# Processing Record 47 of Set 12 | dillon
# Processing Record 48 of Set 12 | bitlis
# Processing Record 49 of Set 12 | tazovskiy
# Processing Record 50 of Set 12 | harper
# Processing Record 1 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 13 | buala
# Processing Record 3 of Set 13 | alice springs
# Processing Record 4 of Set 13 | laguna verde
# Processing Record 5 of Set 13 | san carlos de bariloche
# Processing Record 6 of Set 13 | gwadar
# Processing Record 7 of Set 13 | borgarnes
# Processing Record 8 of Set 13 | pondicherry
# Processing Record 9 of Set 13 | jiazi
# Processing Record 10 of Set 13 | vanderhoof
# Processing Record 11 of Set 13 | damaturu
# Processing Record 12 of Set 13 | borshchiv
# Processing Record 13 of Set 13 | korhogo
# Processing Record 14 of Set 13 | miracema do tocantins
# Processing Record 15 of Set 13 | kirakira
# Processing Record 16 of Set 13 | tocopilla
# Processing Record 17 of Set 13 | praia da vitoria
# Processing Record 18 of Set 13 | uray
# Processing Record 19 of Set 13 | meadow lake
# Processing Record 20 of Set 13 | uzhur
# Processing Record 21 of Set 13 | broome
# Processing Record 22 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 23 of Set 13 | olinda
# Processing Record 24 of Set 13 | ulladulla
# Processing Record 25 of Set 13 | les cayes
# Processing Record 26 of Set 13 | preobrazheniye
# Processing Record 27 of Set 13 | thanh hoa
# Processing Record 28 of Set 13 | ahuimanu
# Processing Record 29 of Set 13 | itarema
# Processing Record 30 of Set 13 | yelizovo
# Processing Record 31 of Set 13 | humaita
# Processing Record 32 of Set 13 | chicama
# Processing Record 33 of Set 13 | biltine
# Processing Record 34 of Set 13 | egvekinot
# Processing Record 35 of Set 13 | krosno
# Processing Record 36 of Set 13 | makinsk
# Processing Record 37 of Set 13 | yumen
# Processing Record 38 of Set 13 | dir
# Processing Record 39 of Set 13 | ahipara
# Processing Record 40 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 13 | kutina
# Processing Record 43 of Set 13 | maarianhamina
# Processing Record 44 of Set 13 | fort frances
# Processing Record 45 of Set 13 | tambongon
# Processing Record 46 of Set 13 | praia
# Processing Record 47 of Set 13 | mogadishu
# Processing Record 48 of Set 13 | fare
# Processing Record 49 of Set 13 | sola
# Processing Record 50 of Set 13 | bakel
# Processing Record 1 of Set 14 | hirara
# Processing Record 2 of Set 14 | samarai
# Processing Record 3 of Set 14 | srednekolymsk
# Processing Record 4 of Set 14 | matveyev kurgan
# Processing Record 5 of Set 14 | cairns
# Processing Record 6 of Set 14 | san rafael
# Processing Record 7 of Set 14 | qaqortoq
# Processing Record 8 of Set 14 | mehamn
# Processing Record 9 of Set 14 | kaitong
# Processing Record 10 of Set 14 | tiarei
# Processing Record 11 of Set 14 | andijon
# Processing Record 12 of Set 14 | subirana
# Processing Record 13 of Set 14 | powell river
# Processing Record 14 of Set 14 | isilkul
# Processing Record 15 of Set 14 | shenjiamen
# Processing Record 16 of Set 14 | cortes
# Processing Record 17 of Set 14 | guerrero negro
# Processing Record 18 of Set 14 | marovoay
# Processing Record 19 of Set 14 | beneditinos
# Processing Record 20 of Set 14 | xichang
# Processing Record 21 of Set 14 | kisangani
# Processing Record 22 of Set 14 | volsk
# Processing Record 23 of Set 14 | beibei
# Processing Record 24 of Set 14 | bafia
# Processing Record 25 of Set 14 | huescar
# Processing Record 26 of Set 14 | seoul
# Processing Record 27 of Set 14 | marataizes
# Processing Record 28 of Set 14 | okhotsk
# Processing Record 29 of Set 14 | sayyan
# Processing Record 30 of Set 14 | mahibadhoo
# Processing Record 31 of Set 14 | bonavista
# Processing Record 32 of Set 14 | launceston
# Processing Record 33 of Set 14 | north platte
# Processing Record 34 of Set 14 | mandalgovi
# Processing Record 35 of Set 14 | lazaro cardenas
# Processing Record 36 of Set 14 | burlington
# Processing Record 37 of Set 14 | saedinenie
# Processing Record 38 of Set 14 | wuwei
# Processing Record 39 of Set 14 | viborg
# Processing Record 40 of Set 14 | shubarshi
# Processing Record 41 of Set 14 | vittoria
# Processing Record 42 of Set 14 | kuragino
# Processing Record 43 of Set 14 | carauari
# Processing Record 44 of Set 14 | tubmanburg
# Processing Record 45 of Set 14 | meulaboh
# Processing Record 46 of Set 14 | borama
# City not found. Skipping...
# Processing Record 47 of Set 14 | aswan
# Processing Record 48 of Set 14 | maracaju
# Processing Record 49 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 14 | makakilo city
# Processing Record 1 of Set 15 | puerto narino
# Processing Record 2 of Set 15 | matara
# Processing Record 3 of Set 15 | rafsanjan
# Processing Record 4 of Set 15 | gazni
# City not found. Skipping...
# Processing Record 5 of Set 15 | khuzdar
# Processing Record 6 of Set 15 | aksha
# Processing Record 7 of Set 15 | bonfim
# Processing Record 8 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 9 of Set 15 | darhan
# Processing Record 10 of Set 15 | cavalcante
# Processing Record 11 of Set 15 | anloga
# Processing Record 12 of Set 15 | sisimiut
# Processing Record 13 of Set 15 | bridlington
# Processing Record 14 of Set 15 | lavrentiya
# Processing Record 15 of Set 15 | reutlingen
# Processing Record 16 of Set 15 | ossora
# Processing Record 17 of Set 15 | marsabit
# Processing Record 18 of Set 15 | harlingen
# Processing Record 19 of Set 15 | volkhov
# Processing Record 20 of Set 15 | pinawa
# Processing Record 21 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 15 | prince rupert
# Processing Record 23 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 15 | tselinnoye
# Processing Record 25 of Set 15 | atbasar
# Processing Record 26 of Set 15 | araouane
# Processing Record 27 of Set 15 | villefranche-de-rouergue
# Processing Record 28 of Set 15 | ajdabiya
# Processing Record 29 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 15 | hobyo
# Processing Record 31 of Set 15 | bonthe
# Processing Record 32 of Set 15 | plastun
# Processing Record 33 of Set 15 | smoky lake
# Processing Record 34 of Set 15 | troyes
# Processing Record 35 of Set 15 | pemangkat
# Processing Record 36 of Set 15 | nouadhibou
# Processing Record 37 of Set 15 | varkkallai
# Processing Record 38 of Set 15 | arlit
# Processing Record 39 of Set 15 | zhigansk
# Processing Record 40 of Set 15 | cedar city
# Processing Record 41 of Set 15 | newport
# Processing Record 42 of Set 15 | port moresby
# Processing Record 43 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 15 | sydney mines
# Processing Record 45 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 46 of Set 15 | altamira
# Processing Record 47 of Set 15 | aktau
# Processing Record 48 of Set 15 | brae
# Processing Record 49 of Set 15 | nabire
# Processing Record 50 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 16 | diego de almagro
# Processing Record 2 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 16 | vavozh
# Processing Record 4 of Set 16 | vrangel
# Processing Record 5 of Set 16 | walvis bay
# Processing Record 6 of Set 16 | auka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     52.45        82          66
# 1    Polunochnoye      RU  60.8697   60.4153     27.37        97          99
# 2    Norman Wells      CA  65.2820 -126.8329     35.64        69          75
# 3     Tuktoyaktuk      CA  69.4541 -133.0374     33.80        86          75
# 4    Ponta Do Sol      PT  32.6667  -17.1000     70.43        70          27
# 5        Karratha      AU -20.7377  116.8463     75.45        34           0
# 6         Rikitea      PF -23.1203 -134.9692     73.78        72           2
# 7          Garowe      SO   8.4054   48.4845     78.08        57           9
# 8      Nanortalik      GL  60.1432  -45.2371     37.08        80           7
# 9         Ushuaia      AR -54.8000  -68.3000     40.66        60           0
#
#    Wind Speed Current Description
# 0       12.33       broken clouds
# 1        4.32     overcast clouds
# 2        5.75       broken clouds
# 3       13.80          light rain
# 4        3.36    scattered clouds
# 5       11.34           clear sky
# 6       19.42           clear sky
# 7       16.75           clear sky
# 8        1.92           clear sky
# 9        8.05           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
